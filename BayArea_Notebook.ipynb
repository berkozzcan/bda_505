# %%
import pandas as pd

# %%
# !pip install psycopg2
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 384.3/384.3 kB 1.9 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for psycopg2: filename=psycopg2-2.9.5-cp39-cp39-macosx_10_9_x86_64.whl size=133933 sha256=fde617a193e426898f1e4496d2366e7e22e5c000adcb614167000b8fe3db34ef
#   Stored in directory: /Users/berkozcan/Library/Caches/pip/wheels/37/c1/ad/4ee49165718dff2c018c9830204ef8e749afdce7919f078586
# Successfully built psycopg2
# ...

# %%
# !pip install ipython-sql
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 kB 937.6 kB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for prettytable: filename=prettytable-0.7.2-py3-none-any.whl size=13695 sha256=fec636877be61d5a1953a034c82da94ad21b57be1aa0242cadecef72f907dc99
#   Stored in directory: /Users/berkozcan/Library/Caches/pip/wheels/75/f7/28/77a076f1fa8cbeda61aca712815d04d7a32435f04a26a2dd7b
# Successfully built prettytable
# ...

# %%
import psycopg2

# %%
conn = psycopg2.connect(
    host="localhost",
    database="postgres",
    user="postgres",
    port = 5432)

# %%
#conn = psycopg2.connect("dbname=postgres user=postgres password=Host1")

# %%
cur = conn.cursor()

# %%
cur.execute("""select id,duration from "BayArea".trip limit 10""")
query_results = cur.fetchall()
print(query_results)
# Out:
# [(4576, 63), (4607, 70), (4130, 71), (4251, 77), (4299, 83), (4927, 103), (4500, 109), (4563, 111), (4760, 113), (4258, 114)]

# %%
# %%capture
# %load_ext sql

# %%
# %sql postgresql://postgres:Host1@localhost/postgres

# %%
# %%sql
#
# SELECT *
#     FROM "BayArea".trip
#     LIMIT 10;
# Out:
#  * postgresql://postgres:***@localhost/postgres
# 10 rows affected.
# ...

# %%
# %%sql
#
# SELECT *
#     FROM "BayArea".status
#     LIMIT 20;
# Out:
#  * postgresql://postgres:***@localhost/postgres
# 20 rows affected.
# [(2, 2, 25, datetime.datetime(2013, 8, 29, 12, 6, 1)),
#  (2, 2, 25, datetime.datetime(2013, 8, 29, 12, 7, 1)),
#  (2, 2, 25, datetime.datetime(2013, 8, 29, 12, 8, 1)),
#  (2, 2, 25, datetime.datetime(2013, 8, 29, 12, 9, 1)),
#  (2, 2, 25, datetime.datetime(2013, 8, 29, 12, 10, 1)),
#  (2, 2, 25, datetime.datetime(2013, 8, 29, 12, 11, 1)),
#  (2, 2, 25, datetime.datetime(2013, 8, 29, 12, 12, 1)),
#  (2, 2, 25, datetime.datetime(2013, 8, 29, 12, 13, 1)),
#  (2, 2, 25, datetime.datetime(2013, 8, 29, 12, 15, 1)),
#  (2, 2, 25, datetime.datetime(2013, 8, 29, 12, 16, 2)),
#  (2, 2, 25, datetime.datetime(2013, 8, 29, 12, 18, 1)),
#  (2, 2, 25, datetime.datetime(2013, 8, 29, 12, 19, 1)),
#  (2, 2, 25, datetime.datetime(2013, 8, 29, 12, 20, 1)),
#  (2, 2, 25, datetime.datetime(2013, 8, 29, 12, 21, 1)),
#  (2, 2, 25, datetime.datetime(2013, 8, 29, 12, 22, 1)),
#  (2, 2, 25, datetime.datetime(2013, 8, 29, 12, 23, 1)),
# ...

# %%
pd.
